# %%
import scanpy as sc
import sys
import seaborn as sns
from matplotlib import pylab as plt
# import matplotlib.text
import os
import matplotlib.backends.backend_pdf as mpdf
import numpy as np
import pandas as pd

headdir="/oak/stanford/groups/smontgom/amarder/t21-proj"
disease_status="Healthy"
sampletype="Liver"

print("Completed.")
# Out:
# Completed.

# %%
suffix=".subset"
fout="10X_" + disease_status + "_" + sampletype + ".umap"+suffix+".cells_removed.h5ad"
# fout="10X_" + disease_status + "_" + sampletype + ".umap.h5ad"
foutpath=headdir + "/out/data/" + fout
print("\n * Reading in data..." + foutpath)
adata=sc.read_h5ad(foutpath)

myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080',
            '#307D7E', '#000000', '#DDEFFF', '#000035', '#7B4F4B', '#A1C299', '#300018', '#C2FF99', '#0AA6D8', '#013349',
            '#00846F', '#8CD0FF', '#3B9700', '#04F757', '#C8A1A1', '#1E6E00', '#DFFB71', '#868E7E', '#513A01', '#CCAA35',
            '#800080', '#DAA520', '#1E90FF', '#3CB371', '#9370DB', '#8FBC8F', '#00FF7F', '#0000CD', '#556B2F', '#FF00FF',
            '#CD853F', '#6B8E23', '#008000', '#6495ED', '#00FF00', '#DC143C', '#FFFF00', '#00FFFF', '#FF4500', '#4169E1',
            '#48D1CC', '#191970', '#9ACD32', '#FFA500', '#00FA9A', '#2E8B57', '#40E0D0', '#D2691E', '#66CDAA', '#FFEFD5',
            '#20B2AA', '#FF0000', '#EEE8AA', '#BDB76B', '#E9967A', '#AFEEEE', '#000080', '#FF8C00', '#B22222', '#5F9EA0',
            '#ADFF2F', '#FFE4B5', '#7B68EE', '#7FFFD4', '#0000FF', '#BA55D3', '#90EE90', '#FFDAB9', '#6A5ACD', '#8B0000',
            '#8A2BE2', '#CD5C5C', '#F08080', '#228B22', '#FFD700', '#006400', '#98FB98', '#00CED1', '#00008B', '#9400D3',
            '#9932CC', '#4B0082', '#F0E68C', '#483D8B', '#008B8B', '#8B008B', '#4682B4']

print("Data read completed.")
# Out:
#  * Reading in data.../oak/stanford/groups/smontgom/amarder/t21-proj/out/data/10X_Healthy_Liver.umap.subset.cells_removed.h5ad
# Data read completed.

# %%
suffix=".subset"
headdir="/oak/stanford/groups/smontgom/amarder/t21-proj"
for disease_status in ["Healthy","DownSyndrome"]:
    for sampletype in ["Liver","Femur"]:
        suffix=".subset"
        fout="10X_" + disease_status + "_" + sampletype + ".umap"+suffix+".cells_removed.h5ad"
        foutpath=headdir + "/out/data/" + fout
        print("\n * Reading in data..." + foutpath)
        adata=sc.read_h5ad(foutpath)
        
        a=[columnName[8:] for columnName in adata.obs.columns if 'leiden_v' in columnName]
        colName="leiden_v" + str(max([int(x) for x in a if x.isdigit()]))
        list_of_cell_types=np.unique(adata.obs[[colName]])
        print(list_of_cell_types)

        

print("Completed.")
# Out:
#  * Reading in data.../oak/stanford/groups/smontgom/amarder/t21-proj/out/data/10X_DownSyndrome_Femur.umap.subset.cells_removed.h5ad
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~/anaconda3/envs/minimal_env/lib/python3.6/site-packages/anndata/_io/utils.py in func_wrapper(elem, *args, **kwargs)
#     176         try:
# --> 177             return func(elem, *args, **kwargs)
#     178         except Exception as e:
#
# ~/anaconda3/envs/minimal_env/lib/python3.6/site-packages/anndata/_io/h5ad.py in read_group(group)
#     534     elif encoding_type in {"csr_matrix", "csc_matrix"}:
# --> 535         return SparseDataset(group).to_memory()
#     536     else:
#
# ~/anaconda3/envs/minimal_env/lib/python3.6/site-packages/anndata/_core/sparse_dataset.py in to_memory(self)
#     371         mtx.data = self.group["data"][...]
# --> 372         mtx.indices = self.group["indices"][...]
#     373         mtx.indptr = self.group["indptr"][...]
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/anaconda3/envs/minimal_env/lib/python3.6/site-packages/h5py/_hl/dataset.py in __getitem__(self, args)
#     561         mshape = (1,) if single_element else selection.mshape
# --> 562         arr = numpy.ndarray(mshape, new_dtype, order='C')
#     563
#
# MemoryError: Unable to allocate 51.0 MiB for an array with shape (13359407,) and data type int32
#
# During handling of the above exception, another exception occurred:
#
# AnnDataReadError                          Traceback (most recent call last)
# <ipython-input-37-6cce7519038c> in <module>
#       7         foutpath=headdir + "/out/data/" + fout
#       8         print("\n * Reading in data..." + foutpath)
# ----> 9         adata=sc.read_h5ad(foutpath)
#      10
#      11         a=[columnName[8:] for columnName in adata.obs.columns if 'leiden_v' in columnName]
#
# ~/anaconda3/envs/minimal_env/lib/python3.6/site-packages/anndata/_io/h5ad.py in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     419                 d[k] = read_dataframe(f[k])
#     420             else:  # Base case
# --> 421                 d[k] = read_attribute(f[k])
#     422
#     423         d["raw"] = _read_raw(f, as_sparse, rdasp)
#
# ~/anaconda3/envs/minimal_env/lib/python3.6/functools.py in wrapper(*args, **kw)
#     805                             '1 positional argument')
#     806
# --> 807         return dispatch(args[0].__class__)(*args, **kw)
#     808
#     809     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/anaconda3/envs/minimal_env/lib/python3.6/site-packages/anndata/_io/utils.py in func_wrapper(elem, *args, **kwargs)
#     182                 parent = _get_parent(elem)
#     183                 raise AnnDataReadError(
# --> 184                     f"Above error raised while reading key {elem.name!r} of "
#     185                     f"type {type(elem)} from {parent}."
#     186                 )
#
# AnnDataReadError: Above error raised while reading key '/X' of type <class 'h5py._hl.group.Group'> from /.

# %%
'PDGFRB' in adata.var.index
# adata["CD34"]
# adata["PDFRB"]
# Out:
# True

# %%
print(adata_3d)

# %%
print("\n * Grouping clusters within broad cell types...")
print("\n * Creating dictionary...")
list_of_cell_types=np.unique(adata.obs[[colName]])
celltypeDict={}
broad_cell_type="Erythroid"; old_cell_types="Erythroid"
celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Myeloid"; old_cell_types="Neutrophils"
celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Myeloid"; old_cell_types="Macrophages"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Myeloid"; old_cell_types="pDCs"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Myeloid"; old_cell_types="cDC2"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Myeloid"; old_cell_types="Kupffer"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Myeloid"; old_cell_types="Monocyte"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Myeloid"; old_cell_types="Osteoclasts"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="HSC/Progenitors"; old_cell_types="HSC"
celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="HSC/Progenitors"; old_cell_types="MPP"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="HSC/Progenitors"; old_cell_types="MEMP"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="HSC/Progenitors"; old_cell_types="Granulocyte"
celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="B cells"; old_cell_types="B cells"
celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Mast cells"; old_cell_types="Mast cells"
celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
broad_cell_type="Megakaryocytes"; old_cell_types="Megakaryocytes"
celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
if disease_status=="DownSyndrome" and sampletype=="Femur":
    broad_cell_type="NK/T cells"; old_cell_types="NK"
    celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
    broad_cell_type="NK/T cells"; old_cell_types="lymphoid"
    celltypeDict[broad_cell_type] += [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]
else:
    broad_cell_type="NK cells"; old_cell_types="NK"
    celltypeDict[broad_cell_type] = [s for s in list_of_cell_types if old_cell_types.upper() in s.upper()]

# print(list_of_cell_types)
list_of_used_cell_types=[]
for sublist in list(celltypeDict.values()):
    for item in sublist:
        list_of_used_cell_types.append(item)

list_of_not_used_cell_types=list(set(list_of_cell_types) - set(list_of_used_cell_types))

celltypeDict["Stroma"] = list_of_not_used_cell_types

print(celltypeDict)

print("\n * Saving new cell type labels to 'cell_type_groups' column in the metadata...")
adata.obs["cell_type_groups"] = np.nan
def create_cell_type_groups(row):
    word=row[colName] 
    topiclist = [topic for topic in celltypeDict if word in celltypeDict[topic]]
    return(topiclist[0])

print("\n * About to run create_cell_type_groups...")
adata.obs["cell_type_groups"] = adata.obs.apply(create_cell_type_groups, axis=1)
print("\n * create_cell_type_groups running complete.")
print("\n * New labels created.")
# Out:
#  * Grouping clusters within broad cell types...
#
#  * Creating dictionary...
# {'Erythroid': ['Cycling erythroid cells', 'Early erythroid cells'], 'Myeloid': ['Neutrophils', 'Inflammatory macrophages', 'pDCs', 'cDC2', 'Kupffer cells', 'Monocyte progenitors'], 'HSC/Progenitors': ['HSCs/MPPs', 'HSCs/MPPs', 'Cycling MEMPs', 'MEMPs', 'Granulocyte progenitors'], 'B cells': ['B cells', 'Pre pro B cells', 'Pro B cells'], 'Mast cells': ['Mast cells'], 'Megakaryocytes': ['Megakaryocytes'], 'NK cells': ['NK cells', 'NK progenitors'], 'Stroma': ['Hepatocytes', 'LSECs']}
#
#  * Saving new cell type labels to 'cell_type_groups' column in the metadata...
#
#  * About to run create_cell_type_groups...
#
#  * create_cell_type_groups running complete.
#
#  * New labels created.

# %%
celltypeDict
# Out:
# {'Erythroid': ['Cycling erythroid cells', 'Early erythroid cells'],
#  'Myeloid': ['Neutrophils',
#   'Inflammatory macrophages',
#   'pDCs',
#   'cDC2',
#   'Kupffer cells',
#   'Monocyte progenitors'],
#  'HSC/Progenitors': ['HSCs/MPPs',
#   'HSCs/MPPs',
#   'Cycling MEMPs',
#   'MEMPs',
#   'Granulocyte progenitors'],
#  'B cells': ['B cells', 'Pre pro B cells', 'Pro B cells'],
#  'Mast cells': ['Mast cells'],
#  'Megakaryocytes': ['Megakaryocytes'],
#  'NK cells': ['NK cells', 'NK progenitors'],
#  'Stroma': ['Hepatocytes', 'LSECs']}

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
# (adata.obs.loc[:,colName]).to_numpy()
le.fit(adata.obs.loc[:,colName])
adata.obs['numerical_labels'] = le.transform(adata.obs.loc[:,colName]).astype(str)

print("Good!")
# adata.obs[[colName]]
# Out:
# Good!

# %%
# print(adata.obsm)
# print(adata.obsm["X_umap_3d"])
# print(adata_3d.obsm["X_umap"])
# f, axs = plt.subplots(1,1,figsize=(26,26))
f, axs = plt.subplots(1,1,figsize=(16,16))
sc.pl.umap(adata_3d, color="cell_type_groups", size=150, palette=myColors, components=["1,2"], ax=axs, show=False, use_raw=False, title=disease_status + ' ' + sampletype,legend_loc="on data",layer="X_umap_3d")
# sc.pl.umap(adata, color="cell_type_groups", size=150, palette=myColors, dimensions=["0,2"], ax=axs, show=False, use_raw=False, title=disease_status + ' ' + sampletype,legend_loc="on data",layer="X_umap_3d")
plt.show()

# %%
direc=headdir + "/out/figures/"
fplotout=direc + "10X_"+disease_status+"_"+sampletype+".umap"+suffix+".pdf"
print("\n * Plotting & saving UMAP... " + fplotout)
f, axs = plt.subplots(1,1,figsize=(26,26))
sns.set(font_scale=2)
sns.set_style("white")
new_plot=sc.pl.umap(adata, color="cell_type_groups", size=150, palette=myColors, components='1,2', ax=axs, show=False, use_raw=False, title=disease_status + ' ' + sampletype,legend_loc="on data")
plt.savefig(fplotout)
plt.show()
plt.close()
print("\n * Plot saved.")

fplotout=direc + "10X_"+disease_status+"_"+sampletype+".umap.no_legend"+suffix+".pdf"
print("\n * Plotting & saving UMAP... " + fplotout)
f, axs = plt.subplots(1,1,figsize=(26,26))
sns.set(font_scale=2)
sns.set_style("white")
new_plot=sc.pl.umap(adata, color="cell_type_groups", size=150, palette=myColors, components='1,2', ax=axs, show=False, use_raw=False, title=disease_status + ' ' + sampletype,legend_loc="None")
plt.savefig(fplotout)
plt.show()
plt.close()
print("\n * Plot saved.")

fplotout=direc + "10X_"+disease_status+"_"+sampletype+".umap"+suffix+".numerical_labels.pdf"
print("\n * Plotting & saving UMAP (numerical labels)... " + fplotout)
f, axs = plt.subplots(1,1,figsize=(26,26))
sns.set(font_scale=2)
sns.set_style("white")
new_plot=sc.pl.umap(adata, color="numerical_labels", size=150, palette=myColors, components='1,2', ax=axs, show=False, use_raw=False, title=disease_status + ' ' + sampletype,legend_loc="on data")
plt.savefig(fplotout)
plt.show()
plt.close()
print("\n * Plot saved.")
# Out:
#  * Plotting & saving UMAP... /oak/stanford/groups/smontgom/amarder/t21-proj/out/figures/10X_Healthy_Liver.umap.subset.pdf
#  * Plot saved.
#
#  * Plotting & saving UMAP... /oak/stanford/groups/smontgom/amarder/t21-proj/out/figures/10X_Healthy_Liver.umap.no_legend.subset.pdf
#  * Plot saved.
#
#  * Plotting & saving UMAP (numerical labels)... /oak/stanford/groups/smontgom/amarder/t21-proj/out/figures/10X_Healthy_Liver.umap.subset.numerical_labels.pdf
#  * Plot saved.

# %%
markerDict= {'HSC/Progenitors' : ['CD34', 'SPINK2'],
    'Erythroid' : ['GATA1', 'KLF1'],
    'Mast cells' : ['HDC', 'CPA3'],
    'Megakaryocytes' : ['ITGA2B', 'GP9'],
    'Myeloid' :[ 'LYZ', 'SPI1'],
    'NK cells' : ['NKG7', 'GZMA'],
    'B cells' : ['CD79A', 'IGHM'],
    'Stroma' : ['ALB', 'AFP']}

fplotout=direc + "10X_"+disease_status+"_"+sampletype+".dotplot.pdf"
print("\n * Plotting & saving UMAP..." + headdir + "/out/figures/"+ fplotout)
f, axs = plt.subplots(1,1,figsize=(14,10))
# pdf = mpdf.PdfPages(fplotout)
# sns.set(font_scale=2)
# sns.set_style("white")
# new_plot=
sc.pl.dotplot(adata,
                   markerDict,
#                    groupby="cell_type_groups",
                   groupby=colName,
                   standard_scale='var',
                   smallest_dot=0.0,
                   dot_min=None,
                   dot_max=None,
                   color_map='Reds',
                   dendrogram=True,
#                    figsize=(12,15),
                   show=False,
                   ax=axs,
                   linewidths=2,swap_axes=True)
# pdf.savefig()
plt.show()
plt.close()
print("\n * Plot saved.")
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden_v7). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: B cells, Cycling MEMPs, Cycling erythroid cells, etc.
# var_group_labels: HSC/Progenitors, Erythroid, Mast cells, etc.
#  * Plotting & saving UMAP.../oak/stanford/groups/smontgom/amarder/t21-proj/out/figures//oak/stanford/groups/smontgom/amarder/t21-proj/out/figures/10X_Healthy_Liver.dotplot.pdf
#  * Plot saved.

# %%
f, axs = plt.subplots(1,1,figsize=(14,10))
# pdf = mpdf.PdfPages(fplotout)
# sns.set(font_scale=2)
# sns.set_style("white")
# new_plot=
categories_order_to_use = ['HSC/Progenitors','Erythroid','Mast cells','Megakaryocytes','Myeloid','NK cells','B cells','Stroma']

sc.pl.dotplot(adata,
                   markerDict,
                   groupby="cell_type_groups",
#                    groupby=colName,
                   standard_scale='var',
                   smallest_dot=0.0,
                   dot_min=None,
                   dot_max=None,
                   color_map='Reds',
                   dendrogram=False,
                   categories_order=categories_order_to_use,
#                    categories_order=['HSC/Progenitors','Erythroid','Mast cells','Megakaryocytes','Myeloid','NK cells','B cells','Stroma'],
#                    figsize=(12,15),
                   show=False,
                   ax=axs,
                   linewidths=2,swap_axes=True)
# pdf.savefig()
plt.show()

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
cluster_to_label_mapping=adata.obs[["numerical_labels",colName,"cell_type_groups"]].drop_duplicates().sort_values("numerical_labels")
fout="10X_" + disease_status + "_" + sampletype + ".cluster_to_label_mapping.csv"
# fout="10X_" + disease_status + "_" + sampletype + ".umap.h5ad"
foutpath=headdir + "/out/data_small/" + fout
print("\n * Saving cluster_to_label_mapping: " + foutpath)
# cluster_to_label_mapping.to_csv(foutpath)
print(cluster_to_label_mapping.to_string(index=False))
pd.set_option('display.max_rows', 10)
print("Done")
# Out:
#  * Saving cluster_to_label_mapping: /oak/stanford/groups/smontgom/amarder/t21-proj/out/data_small/10X_Healthy_Liver.cluster_to_label_mapping.csv
# numerical_labels                 leiden_v7 cell_type_groups
#                0                   B cells          B cells
#                1             Cycling MEMPs  HSC/Progenitors
#                2   Cycling erythroid cells        Erythroid
#                3     Early erythroid cells        Erythroid
#                4   Granulocyte progenitors  HSC/Progenitors
#                5                 HSCs/MPPs  HSC/Progenitors
#                6               Hepatocytes           Stroma
#                7  Inflammatory macrophages          Myeloid
#                8             Kupffer cells          Myeloid
#                9                     LSECs           Stroma
#               10                     MEMPs  HSC/Progenitors
#               11                Mast cells       Mast cells
#               12            Megakaryocytes   Megakaryocytes
#               13      Monocyte progenitors          Myeloid
#               14                  NK cells         NK cells
#               15            NK progenitors         NK cells
#               16               Neutrophils          Myeloid
#               17           Pre pro B cells          B cells
#               18               Pro B cells          B cells
#               19                      cDC2          Myeloid
#               20                      pDCs          Myeloid
# Done

# %%
# print(np.unique(adata.obs[["sorting"]]))
# fout=cellComp_subset
foutpath=headdir + "/out/data_small/" + "10X_" + disease_status + "_" + sampletype + ".cellComp.csv"
adata.obs.loc[:,["patient","sample","sorting","numerical_labels",colName,"cell_type_groups"]].to_csv(foutpath)
print(foutpath)

# print(np.logical_and(np.logical_and(adata.obs["patient"]=="15633", adata.obs["sample"]=="L15633R", adata.obs["sorting"]=="CD45+")))
# cellComp_subset=adata[(adata.obs["patient"]=="15633" and adata.obs["sample"]=="L15633R" and adata.obs["sorting"]=="CD45+") or
#         (adata.obs["patient"]=="15657" and adata.obs["sample"]=="F15657G" and adata.obs["sorting"]=="CD45+") or
#         (adata.obs["patient"]=="15781" and adata.obs["sample"]=="L15781A" and adata.obs["sorting"]=="CD45+") or
#         (adata.obs["patient"]=="15781" and adata.obs["sample"]=="L15781C" and adata.obs["sorting"]=="CD45+")]
# print(cellComp_subset)
# Out:
# /oak/stanford/groups/smontgom/amarder/t21-proj/out/data_small/10X_Healthy_Liver.cellComp.csv

# %%
adata.obs[["patient","sample","sorting"]].drop_duplicates().sort_values("patient")
# Out:
#                       patient   sample     sorting
# AAACCCAAGGAACGCT-1-0    15633  L15633A  CD34+/Lin-
